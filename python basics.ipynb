# %%
True + False # 1 + 0
# Out:
# 1

# %%
True + True # 1+1
# Out:
# 2

# %%
True/False # 1/0 in numpy it will give infinity bcoz it is made for mathematical calculation
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1303991009.py in <cell line: 0>()
# ----> 1 True/False # 1/0 in numpy it will give infinity bcoz it is made for mathematical calculation
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #**Data types**

# %%
name = "Priyanshu" #String
course = "MCA" #String
Age = 23  #int
is_professional = True #Bool
CGPA = 7.2  #float

# %% [markdown]
# #**Operators**

# %%
print( '''+,-,*,/,//,%,** #Arithmetic operators
AND OR NOT #Logical operators
in, not in #Membership operators
<,>,<=,>=, == #comparision operators
= #assingment operators''')
# Out:
# +,-,*,/,//,%,** #Arithmetic operators
# AND OR NOT #Logical operators
# in, not in #Membership operators
# <,>,<=,>=, == #comparision operators
# = #assingment operators

# %% [markdown]
# #**Complex number**

# %%
v = 2+ 3.5 +5j

# %%
type(v)
# Out:
# complex

# %%
v.real
# Out:
# 5.5

# %%
v.imag
# Out:
# 5.0

# %% [markdown]
# Garbage values =  old values are sent in garbage automatically when assigning new values

# %%
a = 2
a
# Out:
# 2

# %%
a= 8
a
# Out:
# 8

# %%
greet = print("hey",end = " ")
name= print("priyanshu")
# Out:
# hey priyanshu

# %% [markdown]
# #**Strings**

# %%
s = "pwSkills"
s[0] # string ke characters ko indexing ki madad se access krte hai
# Out:
# 'p'

# %%
s[0:2] # slice nilak reha hai hence slicing
# Out:
# 'pw'

# %%
s[0:8:2]
# Out:
# 'pSil'

# %%
s[0:len(s):2]
# Out:
# 'pSil'

# %%
s[::2]
# Out:
# 'pSil'

# %% [markdown]
# #Reverse string

# %%
s[::-1]
# Out:
# 'sllikSwp'

# %%
s[2:7:-1]  # do this using number scale to understand
# Out:
# ''

# %%
s[-1:-9:-1]
# Out:
# 'sllikSwp'

# %%
s[8:0:-1]
# Out:
# 'sllikSw'

# %%
s[::-1] # we only give direction to move
# Out:
# 'sllikSwp'

# %%
s[-80] #IndexError: string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3192461789.py in <cell line: 0>()
# ----> 1 s[-80] #IndexError: string index out of range
#
# IndexError: string index out of range

# %%
s[:80:] # because the index is treated as range in slicing
# Out:
# 'pwSkills'

# %%
s[:-80:]
# Out:
# ''

# %% [markdown]
# #***String Functions***
# ###find()
# ###len(string)
# ###count()
# ###upper()
# ###lower()
# ###title()
# ###capitalize()

# %%
p= "this is a string class"

# %%
len(p) # number of characters in string
# Out:
# 22

# %%
p.find("s") # gives the first index of that character/ substring
# Out:
# 3

# %%
p.find("is") # substring
# Out:
# 2

# %%
p.find("Is") # if can't find
# Out:
# -1

# %%
p.count("s") # count the number of repetition of the Substring/char
# Out:
# 5

# %%
p.upper()
# Out:
# 'THIS IS A STRING CLASS'

# %%
p.lower()
# Out:
# 'this is a string class'

# %%
p.capitalize()
# Out:
# 'This is a string class'

# %%
p.title() # first letter of each word
# Out:
# 'This Is A String Class'

# %%
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3893389454.py in <cell line: 0>()
# ----> 1 s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + "1"
# Out:
# 'pwSkills1'

# %%
s*3
# Out:
# 'pwSkillspwSkillspwSkills'

# %%
#backword slash
'hi my name is \'priyanshu\''
# Out:
# "hi my name is 'priyanshu'"
